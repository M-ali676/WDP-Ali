# %%
raaf=["star","moon","hight","lenght"]

# %%
raaf
# Out:
# ['star', 'moon', 'hight', 'lenght']

# %%
rafay2=["tariq","ali","noamn","alitareen","zadi"]

# %%
rafay1.append("noamn")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 rafay1.append("noamn")
#
# NameError: name 'rafay1' is not defined

# %%
rafay.extend(rafay2)

# %%
rafay

# %%
rafay.remove("star")

# %%
rafay

# %%
rafay.insert(2,"tofeq")

# %%
rafay

# %%
def groceryfunc(var):
    if var=="pulses":
        rate=500
    elif var=="spices":
        rate=150
    elif var=="dairy":
        rate=300
    elif var=="rice":
        rate=4000
    elif var=="wheat":
        rate=3000
    else:
        print("Invalid Value, Please Check your outer program")
    return rate

# %%
gorcery=[]
electronic=[]
cart=[]
fandv=[]

def groceryfunc(var):
    if var=="pulses":
        rate=500
    elif var=="spices":
        rate=150
    elif var=="dairy":
        rate=300
    elif var=="rice":
        rate=4000
    elif var=="wheat":
        rate=3000
    else:
        print("Invalid Value, Please Check your outer program")
    return rate

print("Welcome to ecomerce store!")

while True:
    select=input("Which category you want to buy ? \n1.Grocery \n2. Electronic \n3. Fruit and veg:")
    if select=="1":
        while True:
            bucket=["pulses","spices","dairy","rice","wheat"]
            for i in bucket:
                print(i)
            var=input("Please mention what your want to buy from above list:")
            rates=groceryfunc(var)
            if var in bucket:
                print(f"bought item {var} with rate {rates}")
                gorcery.append(var)
                rerun=input("Do you want to buy more from grocery ? (yes/no):").lower()
                if rerun=="yes":
                    continue
                else:
                    break
            rerun=input("Do you want to buy more from grocery ? (yes/no):").lower()
            if rerun=="yes":
                continue
            else:
                break
        else:
            print("Item not found in the bucket, Please check your input")
    #break
# Out:
# Welcome to ecomerce store!
# Which category you want to buy ?
# 1.Grocery
# 2. Electronic
# 3. Fruit and veg: 1
# pulses
# spices
# dairy
# rice
# wheat
# Please mention what your want to buy from above list: pulses
# bought item pulses with rate 500
# Do you want to buy more from grocery ? (yes/no): yes
# pulses
# spices
# dairy
# rice
# wheat
# Please mention what your want to buy from above list: spices
# bought item spices with rate 150
